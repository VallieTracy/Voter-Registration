# %%
# Import dependencies
import pandas as pd

# %%
# Import csv
noVote_2018 = pd.read_csv("Resources/2018_reasons_not_voting.csv")
pd.set_option('display.max_rows', None)

# %%
# Get rid of some of the columns to make it easier to see what I'm doing
noVote_2018.drop([0, 1, 2, 102, 103, 104, 105, 106, 107, 108, 109, 110], axis = 0, inplace = True)
noVote_2018.reset_index(inplace = True)

# %%
# Rename columns
noVote_2018 = noVote_2018.rename(columns = {"Table with row headers in columns A and B, and column headers in rows 5 through 6 and rows 60 through 61.": "Selected Characteristics",
                                            "Unnamed: 1": "Characteristic Breakdown",
                                            "Unnamed: 2": "Not Voting (in thousands)",
                                            "Unnamed: 3": "Illness or Disability (%)",
                                            "Unnamed: 4": "Out of Town (%)",
                                            "Unnamed: 5": "Forgot to Vote (%)",
                                            "Unnamed: 6": "Not Interested (%)",
                                            "Unnamed: 7": "Too Busy, Conflicting Schedule (%)",
                                            "Unnamed: 8": "Transporation Problems (%)",
                                            "Unnamed: 9" : "Did Not Like Candidates or Campaign Issues (%)",
                                            "Unnamed: 10": "Registration Problems (%)",
                                            "Unnamed: 11": "Bad Weather Conditions (%)",
                                            "Unnamed: 12": "Inconvenient Polling Place (%)",
                                            "Unnamed: 13": "Other Reason (%)",
                                            "Unnamed: 14": "Dont Know or Refused (%)"
                                            })
noVote_2018
# Out:
#     index                           Selected Characteristics  \
# 0       3                           Selected characteristics
# 1       4                                                NaN
# 2       5                                              TOTAL
# 3       6                                                Age
# 4       7                                                NaN
# 5       8                                                NaN
# 6       9                                                NaN
# 7      10                                                Sex
# 8      11                                                NaN
# 9      12                           Race and Hispanic origin
# 10     13                                                NaN
# 11     14                                                NaN
# 12     15                                                NaN
# 13     16                                                NaN
# ...

# %%
# Get rid of rows 0 and 1
noVote_2018.drop([0, 1], axis = 0, inplace = True)
noVote_2018.reset_index(inplace = True)

# %%
# Get rid of first two columns
noVote_2018.drop(['level_0', 'index'], axis = 1, inplace = True)
noVote_2018.reset_index(inplace = True)

# %%
# Drop the margin of error portion of the table
noVote_2018.drop(noVote_2018[noVote_2018['index'] > 40].index, inplace = True)

# %%
noVote_2018.dtypes
# Out:
# index                                              int64
# Selected Characteristics                          object
# Characteristic Breakdown                          object
# Not Voting (in thousands)                         object
# Illness or Disability (%)                         object
# Out of Town (%)                                   object
# Forgot to Vote (%)                                object
# Not Interested (%)                                object
# Too Busy, Conflicting Schedule (%)                object
# Transporation Problems (%)                        object
# Did Not Like Candidates or Campaign Issues (%)    object
# Registration Problems (%)                         object
# Bad Weather Conditions (%)                        object
# Inconvenient Polling Place (%)                    object
# Other Reason (%)                                  object
# Dont Know or Refused (%)                          object
# dtype: object

# %%
# Change 'Not Voting (in thousands)' column to deal with the comma
noVote_2018['Not Voting (in thousands)'] = noVote_2018['Not Voting (in thousands)'].str.replace(',', '').astype(int)

# %%
# Change '-' cells with zeros (census specifies this is what the dashes mean)
noVote_2018 = noVote_2018.iloc[:,:].replace('-', '0')

# %%
# Change dataframe to numeric
noVote_2018[['Illness or Disability (%)', 
             'Out of Town (%)',
             'Forgot to Vote (%)',
             'Not Interested (%)',
             'Too Busy, Conflicting Schedule (%)',
             'Transporation Problems (%)',
             'Did Not Like Candidates or Campaign Issues (%)',
             'Registration Problems (%)',
             'Bad Weather Conditions (%)',
             'Inconvenient Polling Place (%)',
             'Other Reason (%)',
             'Dont Know or Refused (%)'
            ]] = noVote_2018[['Illness or Disability (%)', 
             'Out of Town (%)',
             'Forgot to Vote (%)',
             'Not Interested (%)',
             'Too Busy, Conflicting Schedule (%)',
             'Transporation Problems (%)',
             'Did Not Like Candidates or Campaign Issues (%)',
             'Registration Problems (%)',
             'Bad Weather Conditions (%)',
             'Inconvenient Polling Place (%)',
             'Other Reason (%)',
             'Dont Know or Refused (%)'
            ]].apply(pd.to_numeric)
noVote_2018.dtypes
# Out:
# index                                               int64
# Selected Characteristics                           object
# Characteristic Breakdown                           object
# Not Voting (in thousands)                           int32
# Illness or Disability (%)                         float64
# Out of Town (%)                                   float64
# Forgot to Vote (%)                                float64
# Not Interested (%)                                float64
# Too Busy, Conflicting Schedule (%)                float64
# Transporation Problems (%)                        float64
# Did Not Like Candidates or Campaign Issues (%)    float64
# Registration Problems (%)                         float64
# Bad Weather Conditions (%)                        float64
# Inconvenient Polling Place (%)                    float64
# Other Reason (%)                                  float64
# Dont Know or Refused (%)                          float64
# dtype: object

# %%
noVote_2018.head()
# Out:
#    index Selected Characteristics Characteristic Breakdown  \
# 0      0                    TOTAL
# 1      1                      Age           18 to 24 years
# 2      2                      NaN           25 to 44 years
# 3      3                      NaN           45 to 64 years
# 4      4                      NaN        65 years and over
#
#    Not Voting (in thousands)  Illness or Disability (%)  Out of Town (%)  \
# 0                      29089                       12.8              9.2
# 1                       4083                        4.3             13.4
# 2                      11371                        5.6              8.0
# 3                       8825                       12.4             10.5
# 4                       4810                       37.6              6.1
#
#    Forgot to Vote (%)  Not Interested (%)  Too Busy, Conflicting Schedule (%)  \
# 0                 5.6                15.5                                26.9
# ...

# %%
# Replace Selected Characteristics, though I don't know if it's necessary.  May as well since I'm here.
# First, change 'Selected Characteristics' column to string
noVote_2018['Selected Characteristics'] = noVote_2018['Selected Characteristics'].astype('str')
print(type(noVote_2018.iloc[1, 1]))
print(type(noVote_2018.iloc[2, 1]))
print(type(noVote_2018.iloc[4, 1]))
noVote_2018.head()
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
#    index Selected Characteristics Characteristic Breakdown  \
# 0      0                    TOTAL
# 1      1                      Age           18 to 24 years
# 2      2                      nan           25 to 44 years
# 3      3                      nan           45 to 64 years
# 4      4                      nan        65 years and over
#
#    Not Voting (in thousands)  Illness or Disability (%)  Out of Town (%)  \
# 0                      29089                       12.8              9.2
# 1                       4083                        4.3             13.4
# 2                      11371                        5.6              8.0
# 3                       8825                       12.4             10.5
# 4                       4810                       37.6              6.1
#
#    Forgot to Vote (%)  Not Interested (%)  Too Busy, Conflicting Schedule (%)  \
# ...

# %%
noVote_2018.iloc[2:5, 1] = (noVote_2018.iloc[2:5, 1]).replace('nan', 'Age')
noVote_2018.iloc[6, 1] = (noVote_2018.iloc[6, 1]).replace('nan', 'Sex')
noVote_2018.iloc[8:15, 1] = (noVote_2018.iloc[8:15, 1]).replace('nan', 'Race and Hispanic origin')
noVote_2018.iloc[16:19, 1] = (noVote_2018.iloc[16:19, 1]).replace('nan', 'Educational attainment')
noVote_2018.iloc[20, 1] = (noVote_2018.iloc[20, 1]).replace('nan', 'Nativity')
noVote_2018.iloc[22:25, 1] = (noVote_2018.iloc[22:25, 1]).replace('nan', 'Duration of residence')
noVote_2018.iloc[25:29, 1] = (noVote_2018.iloc[25:29, 1]).replace('nan', 'Region')
noVote_2018.iloc[30:41, 1] = (noVote_2018.iloc[30:41, 1]).replace('nan', 'Family income2')

# %%
# Save to a csv
noVote_2018.to_csv('Resources_ETL/2018_reasons_no_vote.csv')

# %% [markdown]
# # 2016
# ---------

# %%
# Import csv
noVote_2016 = pd.read_csv("Resources/2016_reasons_not_voting.csv")
pd.set_option('display.max_rows', None)
noVote_2016
# Out:
#     Table with row headers in columns A and B, and column headers in rows 5 through 6 and rows 60 through 61.  \
# 0    Table 10. Reasons For Not Voting, By Selected ...
# 1                                       (In thousands)
# 2                                                  NaN
# 3                             Selected characteristics
# 4                                                  NaN
# 5                                                TOTAL
# 6                                                  Age
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 Sex
# 11                                                 NaN
# 12                            Race and Hispanic origin
# 13                                                 NaN
# 14                                                 NaN
# ...

# %%
# Get rid of some of the columns to make it easier to see what I'm doing
noVote_2016.drop([0, 1, 2, 102, 103, 104, 105, 106, 107, 108, 109], axis = 0, inplace = True)
noVote_2016.reset_index(inplace = True)

# %%
# Rename columns
noVote_2016 = noVote_2016.rename(columns = {"Table with row headers in columns A and B, and column headers in rows 5 through 6 and rows 60 through 61.": "Selected Characteristics",
                                            "Unnamed: 1": "Characteristic Breakdown",
                                            "Unnamed: 2": "Not Voting (in thousands)",
                                            "Unnamed: 3": "Illness or Disability (%)",
                                            "Unnamed: 4": "Out of Town (%)",
                                            "Unnamed: 5": "Forgot to Vote (%)",
                                            "Unnamed: 6": "Not Interested (%)",
                                            "Unnamed: 7": "Too Busy, Conflicting Schedule (%)",
                                            "Unnamed: 8": "Transporation Problems (%)",
                                            "Unnamed: 9" : "Did Not Like Candidates or Campaign Issues (%)",
                                            "Unnamed: 10": "Registration Problems (%)",
                                            "Unnamed: 11": "Bad Weather Conditions (%)",
                                            "Unnamed: 12": "Inconvenient Polling Place (%)",
                                            "Unnamed: 13": "Other Reason (%)",
                                            "Unnamed: 14": "Dont Know or Refused (%)"
                                            })
noVote_2016.head()
# Out:
#    index  Selected Characteristics Characteristic Breakdown  \
# 0      3  Selected characteristics                      NaN
# 1      4                       NaN                      NaN
# 2      5                     TOTAL
# 3      6                       Age           18 to 24 years
# 4      7                       NaN           25 to 44 years
#
#   Not Voting (in thousands)                       Illness or Disability (%)  \
# 0        Total not voting1   Percent distribution of reasons for not voting
# 1                       NaN                           Illness or disability
# 2                    18,933                                            11.7
# 3                     3,042                                             2.7
# 4                     7,246                                             4.7
#
#   Out of Town (%) Forgot to Vote (%) Not Interested (%)  \
# 0             NaN                NaN                NaN
# ...

# %%
# Get rid of rows 0 and 1
noVote_2016.drop([0, 1], axis = 0, inplace = True)
noVote_2016.reset_index(inplace = True)
noVote_2016.head()
# Out:
#    level_0  index Selected Characteristics Characteristic Breakdown  \
# 0        2      5                    TOTAL
# 1        3      6                      Age           18 to 24 years
# 2        4      7                      NaN           25 to 44 years
# 3        5      8                      NaN           45 to 64 years
# 4        6      9                      NaN        65 years and over
#
#   Not Voting (in thousands) Illness or Disability (%) Out of Town (%)  \
# 0                    18,933                      11.7             7.9
# 1                     3,042                       2.7            13.2
# 2                     7,246                       4.7             7.1
# 3                     5,420                      12.7             7.8
# 4                     3,225                      33.9             5.1
#
#   Forgot to Vote (%) Not Interested (%) Too Busy, Conflicting Schedule (%)  \
# 0                3.0               15.4                               14.3
# ...

# %%
# Get rid of first two columns
noVote_2016.drop(['level_0', 'index'], axis = 1, inplace = True)
noVote_2016.reset_index(inplace = True)
noVote_2016.head()
# Out:
#    index Selected Characteristics Characteristic Breakdown  \
# 0      0                    TOTAL
# 1      1                      Age           18 to 24 years
# 2      2                      NaN           25 to 44 years
# 3      3                      NaN           45 to 64 years
# 4      4                      NaN        65 years and over
#
#   Not Voting (in thousands) Illness or Disability (%) Out of Town (%)  \
# 0                    18,933                      11.7             7.9
# 1                     3,042                       2.7            13.2
# 2                     7,246                       4.7             7.1
# 3                     5,420                      12.7             7.8
# 4                     3,225                      33.9             5.1
#
#   Forgot to Vote (%) Not Interested (%) Too Busy, Conflicting Schedule (%)  \
# 0                3.0               15.4                               14.3
# ...

# %%
# Drop the margin of error portion of the table
noVote_2016.drop(noVote_2016[noVote_2016['index'] > 40].index, inplace = True)
noVote_2016.head()
# Out:
#    index Selected Characteristics Characteristic Breakdown  \
# 0      0                    TOTAL
# 1      1                      Age           18 to 24 years
# 2      2                      NaN           25 to 44 years
# 3      3                      NaN           45 to 64 years
# 4      4                      NaN        65 years and over
#
#   Not Voting (in thousands) Illness or Disability (%) Out of Town (%)  \
# 0                    18,933                      11.7             7.9
# 1                     3,042                       2.7            13.2
# 2                     7,246                       4.7             7.1
# 3                     5,420                      12.7             7.8
# 4                     3,225                      33.9             5.1
#
#   Forgot to Vote (%) Not Interested (%) Too Busy, Conflicting Schedule (%)  \
# 0                3.0               15.4                               14.3
# ...

# %%
# Change 'Not Voting (in thousands)' column to deal with the comma
noVote_2016['Not Voting (in thousands)'] = noVote_2016['Not Voting (in thousands)'].str.replace(',', '').astype(int)
noVote_2016.head()
# Out:
#    index Selected Characteristics Characteristic Breakdown  \
# 0      0                    TOTAL
# 1      1                      Age           18 to 24 years
# 2      2                      NaN           25 to 44 years
# 3      3                      NaN           45 to 64 years
# 4      4                      NaN        65 years and over
#
#    Not Voting (in thousands) Illness or Disability (%) Out of Town (%)  \
# 0                      18933                      11.7             7.9
# 1                       3042                       2.7            13.2
# 2                       7246                       4.7             7.1
# 3                       5420                      12.7             7.8
# 4                       3225                      33.9             5.1
#
#   Forgot to Vote (%) Not Interested (%) Too Busy, Conflicting Schedule (%)  \
# 0                3.0               15.4                               14.3
# ...

# %%
# Change '-' cells with zeros (census specifies this is what the dashes mean)
noVote_2016 = noVote_2016.iloc[:,:].replace('-', '0')
noVote_2016.head()
# Out:
#    index Selected Characteristics Characteristic Breakdown  \
# 0      0                    TOTAL
# 1      1                      Age           18 to 24 years
# 2      2                      NaN           25 to 44 years
# 3      3                      NaN           45 to 64 years
# 4      4                      NaN        65 years and over
#
#    Not Voting (in thousands) Illness or Disability (%) Out of Town (%)  \
# 0                      18933                      11.7             7.9
# 1                       3042                       2.7            13.2
# 2                       7246                       4.7             7.1
# 3                       5420                      12.7             7.8
# 4                       3225                      33.9             5.1
#
#   Forgot to Vote (%) Not Interested (%) Too Busy, Conflicting Schedule (%)  \
# 0                3.0               15.4                               14.3
# ...

# %%
# Change dataframe to numeric
noVote_2016[['Illness or Disability (%)', 
             'Out of Town (%)',
             'Forgot to Vote (%)',
             'Not Interested (%)',
             'Too Busy, Conflicting Schedule (%)',
             'Transporation Problems (%)',
             'Did Not Like Candidates or Campaign Issues (%)',
             'Registration Problems (%)',
             'Bad Weather Conditions (%)',
             'Inconvenient Polling Place (%)',
             'Other Reason (%)',
             'Dont Know or Refused (%)'
            ]] = noVote_2016[['Illness or Disability (%)', 
             'Out of Town (%)',
             'Forgot to Vote (%)',
             'Not Interested (%)',
             'Too Busy, Conflicting Schedule (%)',
             'Transporation Problems (%)',
             'Did Not Like Candidates or Campaign Issues (%)',
             'Registration Problems (%)',
             'Bad Weather Conditions (%)',
             'Inconvenient Polling Place (%)',
             'Other Reason (%)',
             'Dont Know or Refused (%)'
            ]].apply(pd.to_numeric)
noVote_2016.dtypes
# Out:
# index                                               int64
# Selected Characteristics                           object
# Characteristic Breakdown                           object
# Not Voting (in thousands)                           int32
# Illness or Disability (%)                         float64
# Out of Town (%)                                   float64
# Forgot to Vote (%)                                float64
# Not Interested (%)                                float64
# Too Busy, Conflicting Schedule (%)                float64
# Transporation Problems (%)                        float64
# Did Not Like Candidates or Campaign Issues (%)    float64
# Registration Problems (%)                         float64
# Bad Weather Conditions (%)                        float64
# Inconvenient Polling Place (%)                    float64
# Other Reason (%)                                  float64
# Dont Know or Refused (%)                          float64
# dtype: object

# %%
# Replace Selected Characteristics, though I don't know if it's necessary.  May as well since I'm here.
# First, change 'Selected Characteristics' column to string
noVote_2016['Selected Characteristics'] = noVote_2016['Selected Characteristics'].astype('str')
print(type(noVote_2016.iloc[1, 1]))
print(type(noVote_2016.iloc[2, 1]))
print(type(noVote_2016.iloc[4, 1]))
noVote_2016.head()
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
#    index Selected Characteristics Characteristic Breakdown  \
# 0      0                    TOTAL
# 1      1                      Age           18 to 24 years
# 2      2                      nan           25 to 44 years
# 3      3                      nan           45 to 64 years
# 4      4                      nan        65 years and over
#
#    Not Voting (in thousands)  Illness or Disability (%)  Out of Town (%)  \
# 0                      18933                       11.7              7.9
# 1                       3042                        2.7             13.2
# 2                       7246                        4.7              7.1
# 3                       5420                       12.7              7.8
# 4                       3225                       33.9              5.1
#
#    Forgot to Vote (%)  Not Interested (%)  Too Busy, Conflicting Schedule (%)  \
# ...

# %%
noVote_2016.iloc[2:5, 1] = (noVote_2016.iloc[2:5, 1]).replace('nan', 'Age')
noVote_2016.iloc[6, 1] = (noVote_2016.iloc[6, 1]).replace('nan', 'Sex')
noVote_2016.iloc[8:15, 1] = (noVote_2016.iloc[8:15, 1]).replace('nan', 'Race and Hispanic origin')
noVote_2016.iloc[16:19, 1] = (noVote_2016.iloc[16:19, 1]).replace('nan', 'Educational attainment')
noVote_2016.iloc[20, 1] = (noVote_2016.iloc[20, 1]).replace('nan', 'Nativity')
noVote_2016.iloc[22:25, 1] = (noVote_2016.iloc[22:25, 1]).replace('nan', 'Duration of residence')
noVote_2016.iloc[25:29, 1] = (noVote_2016.iloc[25:29, 1]).replace('nan', 'Region')
noVote_2016.iloc[30:41, 1] = (noVote_2016.iloc[30:41, 1]).replace('nan', 'Family income2')

# %%
# Save to a csv
noVote_2016.to_csv('Resources_ETL/2016_reasons_no_vote.csv')

# %% [markdown]
# # 2014
# ---------

# %%
# Import csv
noVote_2014 = pd.read_csv("Resources/2014_reasons_not_voting.csv")
pd.set_option('display.max_rows', None)

# %%
# Get rid of some of the columns to make it easier to see what I'm doing
noVote_2014.drop([0, 1, 2, 45, 46], axis = 0, inplace = True)
noVote_2014.reset_index(inplace = True)

# %%
# Rename columns
noVote_2014 = noVote_2014.rename(columns = {"Table with row headers in column A and column headers in rows 4 through 5.": "Selected Characteristics",
                                            "Unnamed: 1": "Characteristic Breakdown",
                                            "Unnamed: 2": "Not Voting (in thousands)",
                                            "Unnamed: 3": "Illness or Disability (%)",
                                            "Unnamed: 4": "Out of Town (%)",
                                            "Unnamed: 5": "Forgot to Vote (%)",
                                            "Unnamed: 6": "Not Interested (%)",
                                            "Unnamed: 7": "Too Busy, Conflicting Schedule (%)",
                                            "Unnamed: 8": "Transporation Problems (%)",
                                            "Unnamed: 9" : "Did Not Like Candidates or Campaign Issues (%)",
                                            "Unnamed: 10": "Registration Problems (%)",
                                            "Unnamed: 11": "Bad Weather Conditions (%)",
                                            "Unnamed: 12": "Inconvenient Polling Place (%)",
                                            "Unnamed: 13": "Other Reason (%)",
                                            "Unnamed: 14": "Dont Know or Refused (%)"
                                            })
noVote_2014.head()
# Out:
#    index Selected Characteristics Characteristic Breakdown  \
# 0      3                      NaN                      NaN
# 1      4                    Total                      NaN
# 2      5                      Age           18 to 24 years
# 3      6                      NaN           25 to 44 years
# 4      7                      NaN           45 to 64 years
#
#   Not Voting (in thousands) Illness or Disability (%) Out of Town (%)  \
# 0                       NaN     Illness or disability     Out of town
# 1                    47,593                      10.8             9.5
# 2                     6,193                       2.7            13.6
# 3                    19,194                       5.1             7.5
# 4                    15,341                      11.1            10.4
#
#   Forgot to Vote (%) Not Interested (%) Too Busy, Conflicting Schedule (%)  \
# 0     Forgot to vote     Not interested     Too busy, conflicting schedule
# ...

# %%
# Get rid of row 0
noVote_2014.drop([0], axis = 0, inplace = True)
noVote_2014.reset_index(inplace = True)
noVote_2014.head()
# Out:
#    level_0  index Selected Characteristics Characteristic Breakdown  \
# 0        1      4                    Total                      NaN
# 1        2      5                      Age           18 to 24 years
# 2        3      6                      NaN           25 to 44 years
# 3        4      7                      NaN           45 to 64 years
# 4        5      8                      NaN        65 years and over
#
#   Not Voting (in thousands) Illness or Disability (%) Out of Town (%)  \
# 0                    47,593                      10.8             9.5
# 1                     6,193                       2.7            13.6
# 2                    19,194                       5.1             7.5
# 3                    15,341                      11.1            10.4
# 4                     6,864                      33.7             9.4
#
#   Forgot to Vote (%) Not Interested (%) Too Busy, Conflicting Schedule (%)  \
# ...

# %%
# Get rid of first two columns
noVote_2014.drop(['level_0', 'index'], axis = 1, inplace = True)
noVote_2014.reset_index(inplace = True)
noVote_2014.head()
# Out:
#    index Selected Characteristics Characteristic Breakdown  \
# 0      0                    Total                      NaN
# 1      1                      Age           18 to 24 years
# 2      2                      NaN           25 to 44 years
# 3      3                      NaN           45 to 64 years
# 4      4                      NaN        65 years and over
#
#   Not Voting (in thousands) Illness or Disability (%) Out of Town (%)  \
# 0                    47,593                      10.8             9.5
# 1                     6,193                       2.7            13.6
# 2                    19,194                       5.1             7.5
# 3                    15,341                      11.1            10.4
# 4                     6,864                      33.7             9.4
#
#   Forgot to Vote (%) Not Interested (%) Too Busy, Conflicting Schedule (%)  \
# 0                8.3               16.4                               28.2
# ...

# %%
# Change 'Not Voting (in thousands)' column to deal with the comma
noVote_2014['Not Voting (in thousands)'] = noVote_2014['Not Voting (in thousands)'].str.replace(',', '').astype(int)
noVote_2014.head()
# Out:
#    index Selected Characteristics Characteristic Breakdown  \
# 0      0                    Total                      NaN
# 1      1                      Age           18 to 24 years
# 2      2                      NaN           25 to 44 years
# 3      3                      NaN           45 to 64 years
# 4      4                      NaN        65 years and over
#
#    Not Voting (in thousands) Illness or Disability (%) Out of Town (%)  \
# 0                      47593                      10.8             9.5
# 1                       6193                       2.7            13.6
# 2                      19194                       5.1             7.5
# 3                      15341                      11.1            10.4
# 4                       6864                      33.7             9.4
#
#   Forgot to Vote (%) Not Interested (%) Too Busy, Conflicting Schedule (%)  \
# 0                8.3               16.4                               28.2
# ...

# %%
# Change '-' cells with zeros (census specifies this is what the dashes mean)
noVote_2014 = noVote_2014.iloc[:,:].replace('-', '0')
noVote_2014.head()
# Out:
#    index Selected Characteristics Characteristic Breakdown  \
# 0      0                    Total                      NaN
# 1      1                      Age           18 to 24 years
# 2      2                      NaN           25 to 44 years
# 3      3                      NaN           45 to 64 years
# 4      4                      NaN        65 years and over
#
#    Not Voting (in thousands) Illness or Disability (%) Out of Town (%)  \
# 0                      47593                      10.8             9.5
# 1                       6193                       2.7            13.6
# 2                      19194                       5.1             7.5
# 3                      15341                      11.1            10.4
# 4                       6864                      33.7             9.4
#
#   Forgot to Vote (%) Not Interested (%) Too Busy, Conflicting Schedule (%)  \
# 0                8.3               16.4                               28.2
# ...

# %%
# Change dataframe to numeric
noVote_2014[['Illness or Disability (%)', 
             'Out of Town (%)',
             'Forgot to Vote (%)',
             'Not Interested (%)',
             'Too Busy, Conflicting Schedule (%)',
             'Transporation Problems (%)',
             'Did Not Like Candidates or Campaign Issues (%)',
             'Registration Problems (%)',
             'Bad Weather Conditions (%)',
             'Inconvenient Polling Place (%)',
             'Other Reason (%)',
             'Dont Know or Refused (%)'
            ]] = noVote_2014[['Illness or Disability (%)', 
             'Out of Town (%)',
             'Forgot to Vote (%)',
             'Not Interested (%)',
             'Too Busy, Conflicting Schedule (%)',
             'Transporation Problems (%)',
             'Did Not Like Candidates or Campaign Issues (%)',
             'Registration Problems (%)',
             'Bad Weather Conditions (%)',
             'Inconvenient Polling Place (%)',
             'Other Reason (%)',
             'Dont Know or Refused (%)'
            ]].apply(pd.to_numeric)
noVote_2014.dtypes
# Out:
# index                                               int64
# Selected Characteristics                           object
# Characteristic Breakdown                           object
# Not Voting (in thousands)                           int32
# Illness or Disability (%)                         float64
# Out of Town (%)                                   float64
# Forgot to Vote (%)                                float64
# Not Interested (%)                                float64
# Too Busy, Conflicting Schedule (%)                float64
# Transporation Problems (%)                        float64
# Did Not Like Candidates or Campaign Issues (%)    float64
# Registration Problems (%)                         float64
# Bad Weather Conditions (%)                        float64
# Inconvenient Polling Place (%)                    float64
# Other Reason (%)                                  float64
# Dont Know or Refused (%)                          float64
# dtype: object

# %%
# Replace Selected Characteristics, though I don't know if it's necessary.  May as well since I'm here.
# First, change 'Selected Characteristics' column to string
noVote_2014['Selected Characteristics'] = noVote_2014['Selected Characteristics'].astype('str')
print(type(noVote_2014.iloc[1, 1]))
print(type(noVote_2014.iloc[2, 1]))
print(type(noVote_2014.iloc[4, 1]))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
noVote_2014.iloc[2:5, 1] = (noVote_2014.iloc[2:5, 1]).replace('nan', 'Age')
noVote_2014.iloc[6, 1] = (noVote_2014.iloc[6, 1]).replace('nan', 'Sex')
noVote_2014.iloc[8:15, 1] = (noVote_2014.iloc[8:15, 1]).replace('nan', 'Race and Hispanic origin')
noVote_2014.iloc[16:19, 1] = (noVote_2014.iloc[16:19, 1]).replace('nan', 'Educational attainment')
noVote_2014.iloc[20, 1] = (noVote_2014.iloc[20, 1]).replace('nan', 'Nativity')
noVote_2014.iloc[22:25, 1] = (noVote_2014.iloc[22:25, 1]).replace('nan', 'Duration of residence')
noVote_2014.iloc[25:29, 1] = (noVote_2014.iloc[25:29, 1]).replace('nan', 'Region')
noVote_2014.iloc[30:41, 1] = (noVote_2014.iloc[30:41, 1]).replace('nan', 'Family income2')

# %%
# Save to a csv
noVote_2014.to_csv('Resources_ETL/2014_reasons_no_vote.csv')

# %% [markdown]
# # 2012
# ----------

# %%
# Import csv
noVote_2012 = pd.read_csv("Resources/2012_reasons_not_voting.csv")
pd.set_option('display.max_rows', None)

# %%
# Get rid of some of the rows and columns to make it easier to see what I'm doing
noVote_2012.drop([0, 1, 2, 3, 45, 46, 47, 48, 49, 50, 51], axis = 0, inplace = True)
noVote_2012.reset_index(inplace = True)

# %%
# Rename columns
noVote_2012 = noVote_2012.rename(columns = {"Table with row headers in column A and column headers in rows 4 through 5.": "Selected Characteristics",
                                            "Unnamed: 1": "Characteristic Breakdown",
                                            "Unnamed: 2": "Not Voting (in thousands)",
                                            "Unnamed: 3": "Illness or Disability (%)",
                                            "Unnamed: 4": "Out of Town (%)",
                                            "Unnamed: 5": "Forgot to Vote (%)",
                                            "Unnamed: 6": "Not Interested (%)",
                                            "Unnamed: 7": "Too Busy, Conflicting Schedule (%)",
                                            "Unnamed: 8": "Transporation Problems (%)",
                                            "Unnamed: 9" : "Did Not Like Candidates or Campaign Issues (%)",
                                            "Unnamed: 10": "Registration Problems (%)",
                                            "Unnamed: 11": "Bad Weather Conditions (%)",
                                            "Unnamed: 12": "Inconvenient Polling Place (%)",
                                            "Unnamed: 13": "Other Reason (%)",
                                            "Unnamed: 14": "Dont Know or Refused (%)"
                                            })
noVote_2012.head()
# Out:
#    index Selected Characteristics Characteristic Breakdown  \
# 0      4                    Total                      NaN
# 1      5                      Age           18 to 24 years
# 2      6                      NaN           25 to 44 years
# 3      7                      NaN           45 to 64 years
# 4      8                      NaN        65 years and over
#
#   Not Voting (in thousands) Illness or Disability (%) Out of Town (%)  \
# 0                    19,141                      14.0             8.6
# 1                     3,073                       3.1            14.8
# 2                     7,591                       5.6             7.4
# 3                     5,505                      16.5             8.7
# 4                     2,972                      42.0             4.8
#
#   Forgot to Vote (%) Not Interested (%) Too Busy, Conflicting Schedule (%)  \
# 0                3.9               15.7                               18.9
# ...

# %%
# Get rid of first two columns
noVote_2012.drop(['index', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17'], axis = 1, inplace = True)
noVote_2012.reset_index(inplace = True)
noVote_2012.head()
# Out:
#    index Selected Characteristics Characteristic Breakdown  \
# 0      0                    Total                      NaN
# 1      1                      Age           18 to 24 years
# 2      2                      NaN           25 to 44 years
# 3      3                      NaN           45 to 64 years
# 4      4                      NaN        65 years and over
#
#   Not Voting (in thousands) Illness or Disability (%) Out of Town (%)  \
# 0                    19,141                      14.0             8.6
# 1                     3,073                       3.1            14.8
# 2                     7,591                       5.6             7.4
# 3                     5,505                      16.5             8.7
# 4                     2,972                      42.0             4.8
#
#   Forgot to Vote (%) Not Interested (%) Too Busy, Conflicting Schedule (%)  \
# 0                3.9               15.7                               18.9
# ...

# %%
# Change 'Not Voting (in thousands)' column to deal with the comma
noVote_2012['Not Voting (in thousands)'] = noVote_2012['Not Voting (in thousands)'].str.replace(',', '').astype(int)
noVote_2012.head()
# Out:
#    index Selected Characteristics Characteristic Breakdown  \
# 0      0                    Total                      NaN
# 1      1                      Age           18 to 24 years
# 2      2                      NaN           25 to 44 years
# 3      3                      NaN           45 to 64 years
# 4      4                      NaN        65 years and over
#
#    Not Voting (in thousands) Illness or Disability (%) Out of Town (%)  \
# 0                      19141                      14.0             8.6
# 1                       3073                       3.1            14.8
# 2                       7591                       5.6             7.4
# 3                       5505                      16.5             8.7
# 4                       2972                      42.0             4.8
#
#   Forgot to Vote (%) Not Interested (%) Too Busy, Conflicting Schedule (%)  \
# 0                3.9               15.7                               18.9
# ...

# %%
# Change '-' cells with zeros (census specifies this is what the dashes mean)
noVote_2012 = noVote_2012.iloc[:,:].replace('-', '0')
noVote_2012.head()
# Out:
#    index Selected Characteristics Characteristic Breakdown  \
# 0      0                    Total                      NaN
# 1      1                      Age           18 to 24 years
# 2      2                      NaN           25 to 44 years
# 3      3                      NaN           45 to 64 years
# 4      4                      NaN        65 years and over
#
#    Not Voting (in thousands) Illness or Disability (%) Out of Town (%)  \
# 0                      19141                      14.0             8.6
# 1                       3073                       3.1            14.8
# 2                       7591                       5.6             7.4
# 3                       5505                      16.5             8.7
# 4                       2972                      42.0             4.8
#
#   Forgot to Vote (%) Not Interested (%) Too Busy, Conflicting Schedule (%)  \
# 0                3.9               15.7                               18.9
# ...

# %%
# Change dataframe to numeric
noVote_2012[['Illness or Disability (%)', 
             'Out of Town (%)',
             'Forgot to Vote (%)',
             'Not Interested (%)',
             'Too Busy, Conflicting Schedule (%)',
             'Transporation Problems (%)',
             'Did Not Like Candidates or Campaign Issues (%)',
             'Registration Problems (%)',
             'Bad Weather Conditions (%)',
             'Inconvenient Polling Place (%)',
             'Other Reason (%)',
             'Dont Know or Refused (%)'
            ]] = noVote_2012[['Illness or Disability (%)', 
             'Out of Town (%)',
             'Forgot to Vote (%)',
             'Not Interested (%)',
             'Too Busy, Conflicting Schedule (%)',
             'Transporation Problems (%)',
             'Did Not Like Candidates or Campaign Issues (%)',
             'Registration Problems (%)',
             'Bad Weather Conditions (%)',
             'Inconvenient Polling Place (%)',
             'Other Reason (%)',
             'Dont Know or Refused (%)'
            ]].apply(pd.to_numeric)
noVote_2012.dtypes
# Out:
# index                                               int64
# Selected Characteristics                           object
# Characteristic Breakdown                           object
# Not Voting (in thousands)                           int32
# Illness or Disability (%)                         float64
# Out of Town (%)                                   float64
# Forgot to Vote (%)                                float64
# Not Interested (%)                                float64
# Too Busy, Conflicting Schedule (%)                float64
# Transporation Problems (%)                        float64
# Did Not Like Candidates or Campaign Issues (%)    float64
# Registration Problems (%)                         float64
# Bad Weather Conditions (%)                        float64
# Inconvenient Polling Place (%)                    float64
# Other Reason (%)                                  float64
# Dont Know or Refused (%)                          float64
# dtype: object

# %%
# Replace Selected Characteristics, though I don't know if it's necessary.  May as well since I'm here.
# First, change 'Selected Characteristics' column to string
noVote_2012['Selected Characteristics'] = noVote_2012['Selected Characteristics'].astype('str')
print(type(noVote_2012.iloc[1, 1]))
print(type(noVote_2012.iloc[2, 1]))
print(type(noVote_2012.iloc[4, 1]))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
noVote_2012.iloc[2:5, 1] = (noVote_2012.iloc[2:5, 1]).replace('nan', 'Age')
noVote_2012.iloc[6, 1] = (noVote_2012.iloc[6, 1]).replace('nan', 'Sex')
noVote_2012.iloc[8:15, 1] = (noVote_2012.iloc[8:15, 1]).replace('nan', 'Race and Hispanic origin')
noVote_2012.iloc[16:19, 1] = (noVote_2012.iloc[16:19, 1]).replace('nan', 'Educational attainment')
noVote_2012.iloc[20, 1] = (noVote_2012.iloc[20, 1]).replace('nan', 'Nativity')
noVote_2012.iloc[22:25, 1] = (noVote_2012.iloc[22:25, 1]).replace('nan', 'Duration of residence')
noVote_2012.iloc[25:29, 1] = (noVote_2012.iloc[25:29, 1]).replace('nan', 'Region')
noVote_2012.iloc[30:41, 1] = (noVote_2012.iloc[30:41, 1]).replace('nan', 'Family income2')

# %%
# Save to a csv
noVote_2012.to_csv('Resources_ETL/2012_reasons_no_vote.csv')

# %% [markdown]
# # 2010
# --------

# %%
# Import csv
noVote_2010 = pd.read_csv("Resources/2010_reasons_not_voting.csv")
pd.set_option('display.max_rows', None)
noVote_2010.head()
# Out:
#   Table 10.  Reasons For Not Voting, By Selected Characteristics:  November 2010  \
# 0      (Population 18 years and older, in thousands)
# 1                                     Characteristic
# 2                                                NaN
# 3                                              TOTAL
# 4                                                Age
#
#        Unnamed: 1 Unnamed: 2                                      Unnamed: 3  \
# 0             NaN        NaN                                             NaN
# 1             NaN      Total  Percent distribution of reasons for not voting
# 2             NaN        NaN                           Illness or disability
# 3             NaN     39,453                                            11.3
# 4  18 to 24 years      5,863                                             3.4
#
#     Unnamed: 4      Unnamed: 5      Unnamed: 6  \
# 0          NaN             NaN             NaN
# 1          NaN             NaN             NaN
# ...

# %%
# Get rid of some of the rows and columns to make it easier to see what I'm doing
noVote_2010.drop([0, 1, 2, 44, 45, 46, 47, 48, 49], axis = 0, inplace = True)
noVote_2010.reset_index(inplace = True)

# %%
# Rename columns
noVote_2010 = noVote_2010.rename(columns = {"Table 10.  Reasons For Not Voting, By Selected Characteristics:  November 2010": "Selected Characteristics",
                                            "Unnamed: 1": "Characteristic Breakdown",
                                            "Unnamed: 2": "Not Voting (in thousands)",
                                            "Unnamed: 3": "Illness or Disability (%)",
                                            "Unnamed: 4": "Out of Town (%)",
                                            "Unnamed: 5": "Forgot to Vote (%)",
                                            "Unnamed: 6": "Not Interested (%)",
                                            "Unnamed: 7": "Too Busy, Conflicting Schedule (%)",
                                            "Unnamed: 8": "Transporation Problems (%)",
                                            "Unnamed: 9" : "Did Not Like Candidates or Campaign Issues (%)",
                                            "Unnamed: 10": "Registration Problems (%)",
                                            "Unnamed: 11": "Bad Weather Conditions (%)",
                                            "Unnamed: 12": "Inconvenient Polling Place (%)",
                                            "Unnamed: 13": "Other Reason (%)",
                                            "Unnamed: 14": "Dont Know or Refused (%)"
                                            })
noVote_2010.head()
# Out:
#    index Selected Characteristics Characteristic Breakdown  \
# 0      3                    TOTAL                      NaN
# 1      4                      Age           18 to 24 years
# 2      5                      NaN           25 to 44 years
# 3      6                      NaN           45 to 64 years
# 4      7                      NaN        65 years and over
#
#   Not Voting (in thousands) Illness or Disability (%) Out of Town (%)  \
# 0                    39,453                      11.3             9.2
# 1                     5,863                       3.4            12.4
# 2                    16,633                       5.7             7.6
# 3                    11,782                      12.2            10.6
# 4                     5,176                      36.4             7.1
#
#   Forgot to Vote (%) Not Interested (%) Too Busy, Conflicting Schedule (%)  \
# 0                8.0               16.4                               26.6
# ...

# %%
# Get rid of first column plus last three columns
noVote_2010.drop(['index', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17'], axis = 1, inplace = True)
noVote_2010.reset_index(inplace = True)
noVote_2010.head()
# Out:
#    index Selected Characteristics Characteristic Breakdown  \
# 0      0                    TOTAL                      NaN
# 1      1                      Age           18 to 24 years
# 2      2                      NaN           25 to 44 years
# 3      3                      NaN           45 to 64 years
# 4      4                      NaN        65 years and over
#
#   Not Voting (in thousands) Illness or Disability (%) Out of Town (%)  \
# 0                    39,453                      11.3             9.2
# 1                     5,863                       3.4            12.4
# 2                    16,633                       5.7             7.6
# 3                    11,782                      12.2            10.6
# 4                     5,176                      36.4             7.1
#
#   Forgot to Vote (%) Not Interested (%) Too Busy, Conflicting Schedule (%)  \
# 0                8.0               16.4                               26.6
# ...

# %%
# Change 'Not Voting (in thousands)' column to deal with the comma
noVote_2010['Not Voting (in thousands)'] = noVote_2010['Not Voting (in thousands)'].str.replace(',', '').astype(int)
noVote_2010.head()
# Out:
#    index Selected Characteristics Characteristic Breakdown  \
# 0      0                    TOTAL                      NaN
# 1      1                      Age           18 to 24 years
# 2      2                      NaN           25 to 44 years
# 3      3                      NaN           45 to 64 years
# 4      4                      NaN        65 years and over
#
#    Not Voting (in thousands) Illness or Disability (%) Out of Town (%)  \
# 0                      39453                      11.3             9.2
# 1                       5863                       3.4            12.4
# 2                      16633                       5.7             7.6
# 3                      11782                      12.2            10.6
# 4                       5176                      36.4             7.1
#
#   Forgot to Vote (%) Not Interested (%) Too Busy, Conflicting Schedule (%)  \
# 0                8.0               16.4                               26.6
# ...

# %%
# Change '-' cells with zeros (census specifies this is what the dashes mean)
noVote_2010 = noVote_2010.iloc[:,:].replace('-', '0')

# %%
# Change dataframe to numeric
noVote_2010[['Illness or Disability (%)', 
             'Out of Town (%)',
             'Forgot to Vote (%)',
             'Not Interested (%)',
             'Too Busy, Conflicting Schedule (%)',
             'Transporation Problems (%)',
             'Did Not Like Candidates or Campaign Issues (%)',
             'Registration Problems (%)',
             'Bad Weather Conditions (%)',
             'Inconvenient Polling Place (%)',
             'Other Reason (%)',
             'Dont Know or Refused (%)'
            ]] = noVote_2010[['Illness or Disability (%)', 
             'Out of Town (%)',
             'Forgot to Vote (%)',
             'Not Interested (%)',
             'Too Busy, Conflicting Schedule (%)',
             'Transporation Problems (%)',
             'Did Not Like Candidates or Campaign Issues (%)',
             'Registration Problems (%)',
             'Bad Weather Conditions (%)',
             'Inconvenient Polling Place (%)',
             'Other Reason (%)',
             'Dont Know or Refused (%)'
            ]].apply(pd.to_numeric)

# %%
# Replace Selected Characteristics, though I don't know if it's necessary.  May as well since I'm here.
# First, change 'Selected Characteristics' column to string
noVote_2010['Selected Characteristics'] = noVote_2010['Selected Characteristics'].astype('str')
print(type(noVote_2010.iloc[1, 1]))
print(type(noVote_2010.iloc[2, 1]))
print(type(noVote_2010.iloc[4, 1]))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
noVote_2010.iloc[2:5, 1] = (noVote_2010.iloc[2:5, 1]).replace('nan', 'Age')
noVote_2010.iloc[6, 1] = (noVote_2010.iloc[6, 1]).replace('nan', 'Sex')
noVote_2010.iloc[8:15, 1] = (noVote_2010.iloc[8:15, 1]).replace('nan', 'Race and Hispanic origin')
noVote_2010.iloc[16:19, 1] = (noVote_2010.iloc[16:19, 1]).replace('nan', 'Educational attainment')
noVote_2010.iloc[20, 1] = (noVote_2010.iloc[20, 1]).replace('nan', 'Nativity')
noVote_2010.iloc[22:25, 1] = (noVote_2010.iloc[22:25, 1]).replace('nan', 'Duration of residence')
noVote_2010.iloc[25:29, 1] = (noVote_2010.iloc[25:29, 1]).replace('nan', 'Region')
noVote_2010.iloc[30:41, 1] = (noVote_2010.iloc[30:41, 1]).replace('nan', 'Family income2')

# %%
# Save to a csv
noVote_2010.to_csv('Resources_ETL/2010_reasons_no_vote.csv')

# %% [markdown]
# # 2008
# -------

# %%
# Import csv 
# NOTE: Had to save this file in csv utf-8 format
noVote_2008 = pd.read_csv("Resources/2008_reasons_not_voting.csv")#, 'utf-8')
pd.set_option('display.max_rows', None)
noVote_2008.head()
# Out:
#   Table with row headers in column A and column headers in rows 5 through 7.  \
# 0  Table 12. Reasons for Not Voting, by Selected ...
# 1                                     (In thousands)
# 2                   (leading dots indicate subparts)
# 3                                     Characteristic
# 4                                                NaN
#
#   Unnamed: 1                                      Unnamed: 2   Unnamed: 3  \
# 0        NaN                                             NaN          NaN
# 1        NaN                                             NaN          NaN
# 2        NaN                                             NaN          NaN
# 3      Total  Percent distribution of reasons for not voting          NaN
# 4        NaN                           Illness or disability  Out of town
#
#        Unnamed: 4      Unnamed: 5                      Unnamed: 6  \
# 0             NaN             NaN                             NaN
# ...

# %%
# Get rid of some of the rows and columns to make it easier to see what I'm doing
noVote_2008.drop([0, 1, 2, 3, 4, 5, 7, 56, 57, 58, 59, 60, 61, 62, 63, 64, 65, 66, 67], axis = 0, inplace = True)
noVote_2008.reset_index(inplace = True)
noVote_2008.head()
# Out:
#    index  \
# 0      6
# 1      8
# 2      9
# 3     10
# 4     11
#
#   Table with row headers in column A and column headers in rows 5 through 7.  \
# 0                                              TOTAL
# 1                                                Age
# 2                                    .18 to 24 years
# 3                                    .25 to 44 years
# 4                                    .45 to 64 years
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0     15,167       14.9        8.8        2.6       13.4       17.5
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2      2,567        3.2       14.2        4.5       12.1         21
# 3      5,819        6.8        8.4        2.8       14.2       24.3
# 4      4,201       14.8        8.3        1.8       15.2       14.9
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# ...

# %%
# Rename columns
noVote_2008 = noVote_2008.rename(columns = {"Table with row headers in column A and column headers in rows 5 through 7.": "Characteristic Breakdown",
                                            "Unnamed: 1": "Not Voting (in thousands)",
                                            "Unnamed: 2": "Illness or Disability (%)",
                                            "Unnamed: 3": "Out of Town (%)",
                                            "Unnamed: 4": "Forgot to Vote (%)",
                                            "Unnamed: 5": "Not Interested (%)",
                                            "Unnamed: 6": "Too Busy, Conflicting Schedule (%)",
                                            "Unnamed: 7": "Transporation Problems (%)",
                                            "Unnamed: 8" : "Did Not Like Candidates or Campaign Issues (%)",
                                            "Unnamed: 9": "Registration Problems (%)",
                                            "Unnamed: 10": "Bad Weather Conditions (%)",
                                            "Unnamed: 11": "Inconvenient Polling Place (%)",
                                            "Unnamed: 12": "Other Reason (%)",
                                            "Unnamed: 13": "Dont Know or Refused (%)"
                                            })
noVote_2008.head()
# Out:
#    index Characteristic Breakdown Not Voting (in thousands)  \
# 0      6                    TOTAL                    15,167
# 1      8                      Age                       NaN
# 2      9          .18 to 24 years                     2,567
# 3     10          .25 to 44 years                     5,819
# 4     11          .45 to 64 years                     4,201
#
#   Illness or Disability (%) Out of Town (%) Forgot to Vote (%)  \
# 0                      14.9             8.8                2.6
# 1                       NaN             NaN                NaN
# 2                       3.2            14.2                4.5
# 3                       6.8             8.4                2.8
# 4                      14.8             8.3                1.8
#
#   Not Interested (%) Too Busy, Conflicting Schedule (%)  \
# 0               13.4                               17.5
# 1                NaN                                NaN
# ...

# %%
# Delete rows: Age, Sex, Race and Hispanic Origin, Education attainment, Nativity, Tenure, Region, Annual Family Income
noVote_2008.drop([1, 6, 9, 18, 23, 26, 31, 36], axis = 0, inplace = True)
noVote_2008.reset_index(inplace = True)
noVote_2008.head()
# Out:
#    level_0  index Characteristic Breakdown Not Voting (in thousands)  \
# 0        0      6                    TOTAL                    15,167
# 1        2      9          .18 to 24 years                     2,567
# 2        3     10          .25 to 44 years                     5,819
# 3        4     11          .45 to 64 years                     4,201
# 4        5     12       .65 years and over                     2,581
#
#   Illness or Disability (%) Out of Town (%) Forgot to Vote (%)  \
# 0                      14.9             8.8                2.6
# 1                       3.2            14.2                4.5
# 2                       6.8             8.4                2.8
# 3                      14.8             8.3                1.8
# 4                      45.3             5.1                1.3
#
#   Not Interested (%) Too Busy, Conflicting Schedule (%)  \
# 0               13.4                               17.5
# ...

# %%
# Get rid of level_0 and index
noVote_2008.drop(['level_0', 'index'], axis = 1, inplace = True)
noVote_2008.reset_index(inplace = True)
noVote_2008.head()
# Out:
#    index Characteristic Breakdown Not Voting (in thousands)  \
# 0      0                    TOTAL                    15,167
# 1      1          .18 to 24 years                     2,567
# 2      2          .25 to 44 years                     5,819
# 3      3          .45 to 64 years                     4,201
# 4      4       .65 years and over                     2,581
#
#   Illness or Disability (%) Out of Town (%) Forgot to Vote (%)  \
# 0                      14.9             8.8                2.6
# 1                       3.2            14.2                4.5
# 2                       6.8             8.4                2.8
# 3                      14.8             8.3                1.8
# 4                      45.3             5.1                1.3
#
#   Not Interested (%) Too Busy, Conflicting Schedule (%)  \
# 0               13.4                               17.5
# 1               12.1                                 21
# ...

# %%
# Change 'Not Voting (in thousands)' column to deal with the comma
noVote_2008['Not Voting (in thousands)'] = noVote_2008['Not Voting (in thousands)'].str.replace(',', '').astype(int)

# Change '-' cells with zeros (census specifies this is what the dashes mean)
noVote_2008 = noVote_2008.iloc[:,:].replace('-', '0')

# %%
# Remove the '.' at the start of each cell for column 'Characteristic Breakdown'
for i in range(1, 41):
    noVote_2008.iloc[i,1] = (noVote_2008.iloc[i,1])[1:]

# %%
# Row 8 had two periods, so need to remove the second
noVote_2008.iloc[8,1] = (noVote_2008.iloc[8,1])[1:]
noVote_2008.head()
# Out:
#    index Characteristic Breakdown  Not Voting (in thousands)  \
# 0      0                    TOTAL                      15167
# 1      1           18 to 24 years                       2567
# 2      2           25 to 44 years                       5819
# 3      3           45 to 64 years                       4201
# 4      4        65 years and over                       2581
#
#   Illness or Disability (%) Out of Town (%) Forgot to Vote (%)  \
# 0                      14.9             8.8                2.6
# 1                       3.2            14.2                4.5
# 2                       6.8             8.4                2.8
# 3                      14.8             8.3                1.8
# 4                      45.3             5.1                1.3
#
#   Not Interested (%) Too Busy, Conflicting Schedule (%)  \
# 0               13.4                               17.5
# 1               12.1                                 21
# ...

# %%
noVote_2008.insert(loc=1, column='Selected Characteristics', value=noVote_2010['Selected Characteristics'])

# %%
noVote_2008.head()
# Out:
#    index Selected Characteristics Characteristic Breakdown  \
# 0      0                    TOTAL                    TOTAL
# 1      1                      Age           18 to 24 years
# 2      2                      Age           25 to 44 years
# 3      3                      Age           45 to 64 years
# 4      4                      Age        65 years and over
#
#    Not Voting (in thousands) Illness or Disability (%) Out of Town (%)  \
# 0                      15167                      14.9             8.8
# 1                       2567                       3.2            14.2
# 2                       5819                       6.8             8.4
# 3                       4201                      14.8             8.3
# 4                       2581                      45.3             5.1
#
#   Forgot to Vote (%) Not Interested (%) Too Busy, Conflicting Schedule (%)  \
# 0                2.6               13.4                               17.5
# ...

# %%
# Change dataframe to numeric
noVote_2008[['Illness or Disability (%)', 
             'Out of Town (%)',
             'Forgot to Vote (%)',
             'Not Interested (%)',
             'Too Busy, Conflicting Schedule (%)',
             'Transporation Problems (%)',
             'Did Not Like Candidates or Campaign Issues (%)',
             'Registration Problems (%)',
             'Bad Weather Conditions (%)',
             'Inconvenient Polling Place (%)',
             'Other Reason (%)',
             'Dont Know or Refused (%)'
            ]] = noVote_2008[['Illness or Disability (%)', 
             'Out of Town (%)',
             'Forgot to Vote (%)',
             'Not Interested (%)',
             'Too Busy, Conflicting Schedule (%)',
             'Transporation Problems (%)',
             'Did Not Like Candidates or Campaign Issues (%)',
             'Registration Problems (%)',
             'Bad Weather Conditions (%)',
             'Inconvenient Polling Place (%)',
             'Other Reason (%)',
             'Dont Know or Refused (%)'
            ]].apply(pd.to_numeric)

# %%
# Replace Selected Characteristics, though I don't know if it's necessary.  May as well since I'm here.
# First, change 'Selected Characteristics' column to string
noVote_2008['Selected Characteristics'] = noVote_2008['Selected Characteristics'].astype('str')
print(type(noVote_2010.iloc[1, 1]))
print(type(noVote_2010.iloc[2, 1]))
print(type(noVote_2010.iloc[4, 1]))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
# Save to a csv
noVote_2008.to_csv('Resources_ETL/2008_reasons_no_vote.csv')

# %% [markdown]
# # 2006
# --------

# %%
# Import csv 
# NOTE: Had to save this file in csv utf-8 format
noVote_2006 = pd.read_csv("Resources/2006_reasons_not_voting.csv")
pd.set_option('display.max_rows', None)
noVote_2006.head()
# Out:
#   Table with row headers in column A and column headers in rows 5 through 7.  \
# 0  Table 12. Reasons for Not Voting, by Selected ...
# 1                                     (In thousands)
# 2                   (leading dots indicate subparts)
# 3                                     Characteristic
# 4                                                NaN
#
#   Unnamed: 1                                      Unnamed: 2   Unnamed: 3  \
# 0        NaN                                             NaN          NaN
# 1        NaN                                             NaN          NaN
# 2        NaN                                             NaN          NaN
# 3      Total  Percent distribution of reasons for not voting          NaN
# 4        NaN                           Illness or disability  Out of town
#
#        Unnamed: 4      Unnamed: 5                      Unnamed: 6  \
# 0             NaN             NaN                             NaN
# ...

# %%
# Get rid of some of the rows and columns to make it easier to see what I'm doing
noVote_2006.drop([0, 1, 2, 3, 4, 5, 7, 8, 13, 16, 25, 30, 33, 38, 43, 56, 57, 58, 59, 60, 61, 62, 63, 64], axis = 0, inplace = True)
noVote_2006.reset_index(inplace = True)

# %%
# Rename columns
noVote_2006 = noVote_2006.rename(columns = {"Table with row headers in column A and column headers in rows 5 through 7.": "Characteristic Breakdown",
                                            "Unnamed: 1": "Not Voting (in thousands)",
                                            "Unnamed: 2": "Illness or Disability (%)",
                                            "Unnamed: 3": "Out of Town (%)",
                                            "Unnamed: 4": "Forgot to Vote (%)",
                                            "Unnamed: 5": "Not Interested (%)",
                                            "Unnamed: 6": "Too Busy, Conflicting Schedule (%)",
                                            "Unnamed: 7": "Transporation Problems (%)",
                                            "Unnamed: 8" : "Did Not Like Candidates or Campaign Issues (%)",
                                            "Unnamed: 9": "Registration Problems (%)",
                                            "Unnamed: 10": "Bad Weather Conditions (%)",
                                            "Unnamed: 11": "Inconvenient Polling Place (%)",
                                            "Unnamed: 12": "Other Reason (%)",
                                            "Unnamed: 13": "Dont Know or Refused (%)"
                                            })
noVote_2006.head()
# Out:
#    index Characteristic Breakdown Not Voting (in thousands)  \
# 0      6                    TOTAL                    39,728
# 1      9          .18 to 24 years                     6,030
# 2     10          .25 to 44 years                    16,883
# 3     11          .45 to 64 years                    11,446
# 4     12       .65 years and over                     5,369
#
#   Illness or Disability (%) Out of Town (%) Forgot to Vote (%)  \
# 0                      12.4            10.7                5.7
# 1                       2.7            13.9                6.3
# 2                       6.1             9.1                5.9
# 3                      12.4            12.4                5.4
# 4                      42.8             8.4                4.5
#
#   Not Interested (%) Too Busy, Conflicting Schedule (%)  \
# 0               11.5                               27.3
# 1               11.7                               29.5
# ...

# %%
# Reset index
noVote_2006.drop(['index'], axis = 1, inplace = True)
noVote_2006.reset_index(inplace = True)
noVote_2006.head()
# Out:
#    index Characteristic Breakdown Not Voting (in thousands)  \
# 0      0                    TOTAL                    39,728
# 1      1          .18 to 24 years                     6,030
# 2      2          .25 to 44 years                    16,883
# 3      3          .45 to 64 years                    11,446
# 4      4       .65 years and over                     5,369
#
#   Illness or Disability (%) Out of Town (%) Forgot to Vote (%)  \
# 0                      12.4            10.7                5.7
# 1                       2.7            13.9                6.3
# 2                       6.1             9.1                5.9
# 3                      12.4            12.4                5.4
# 4                      42.8             8.4                4.5
#
#   Not Interested (%) Too Busy, Conflicting Schedule (%)  \
# 0               11.5                               27.3
# 1               11.7                               29.5
# ...

# %%
# Change 'Not Voting (in thousands)' column to deal with the comma
noVote_2006['Not Voting (in thousands)'] = noVote_2006['Not Voting (in thousands)'].str.replace(',', '').astype(int)

# Change '-' cells with zeros (census specifies this is what the dashes mean)
noVote_2006 = noVote_2006.iloc[:,:].replace('-', '0')

# %%
# Remove the '.' at the start of each cell for column 'Characteristic Breakdown'
for i in range(1, 41):
    noVote_2006.iloc[i,1] = (noVote_2006.iloc[i,1])[1:]

# %%
# Row 8 has two periods, so need to remove the second
noVote_2006.iloc[8,1] = (noVote_2006.iloc[8,1])[1:]

# %%
# Insert Selected Characteristics column into position 1
noVote_2006.insert(loc=1, column='Selected Characteristics', value=noVote_2008['Selected Characteristics'])

# %%
# Change dataframe to numeric
noVote_2006[['Illness or Disability (%)', 
             'Out of Town (%)',
             'Forgot to Vote (%)',
             'Not Interested (%)',
             'Too Busy, Conflicting Schedule (%)',
             'Transporation Problems (%)',
             'Did Not Like Candidates or Campaign Issues (%)',
             'Registration Problems (%)',
             'Bad Weather Conditions (%)',
             'Inconvenient Polling Place (%)',
             'Other Reason (%)',
             'Dont Know or Refused (%)'
            ]] = noVote_2006[['Illness or Disability (%)', 
             'Out of Town (%)',
             'Forgot to Vote (%)',
             'Not Interested (%)',
             'Too Busy, Conflicting Schedule (%)',
             'Transporation Problems (%)',
             'Did Not Like Candidates or Campaign Issues (%)',
             'Registration Problems (%)',
             'Bad Weather Conditions (%)',
             'Inconvenient Polling Place (%)',
             'Other Reason (%)',
             'Dont Know or Refused (%)'
            ]].apply(pd.to_numeric)

# %%
# Replace Selected Characteristics, though I don't know if it's necessary.  May as well since I'm here.
# First, change 'Selected Characteristics' column to string
noVote_2006['Selected Characteristics'] = noVote_2006['Selected Characteristics'].astype('str')
print(type(noVote_2006.iloc[1, 1]))
print(type(noVote_2006.iloc[2, 1]))
print(type(noVote_2006.iloc[4, 1]))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
# Save to a csv
noVote_2006.to_csv('Resources_ETL/2006_reasons_no_vote.csv')

# %% [markdown]
# # 2004

# %%
# Import csv
noVote_2004 = pd.read_csv("Resources/2004_reasons_not_voting.csv")
pd.set_option('display.max_rows', None)
noVote_2004.head()
# Out:
#   Table with row headers in column A and column headers in rows 5 through 7.  \
# 0  Table 12. Reasons for Not Voting, by Selected ...
# 1                                     (In thousands)
# 2                   (leading dots indicate subparts)
# 3                                     Characteristic
# 4                                                NaN
#
#   Unnamed: 1                                      Unnamed: 2   Unnamed: 3  \
# 0        NaN                                             NaN          NaN
# 1        NaN                                             NaN          NaN
# 2        NaN                                             NaN          NaN
# 3      Total  Percent distribution of reasons for not voting          NaN
# 4        NaN                           Illness or disability  Out of town
#
#        Unnamed: 4      Unnamed: 5                      Unnamed: 6  \
# 0             NaN             NaN                             NaN
# ...

# %%
# Get rid of some of the rows and columns to make it easier to see what I'm doing
noVote_2004.drop([0, 1, 2, 3, 4, 5, 7, 8, 13, 16, 26, 31, 32, 33], axis = 0, inplace = True)
noVote_2004.reset_index(inplace = True)

# %%
noVote_2004.head()
# Out:
#    index  \
# 0      6
# 1      9
# 2     10
# 3     11
# 4     12
#
#   Table with row headers in column A and column headers in rows 5 through 7.  \
# 0                                              TOTAL
# 1                                    .18 to 24 years
# 2                                    .25 to 44 years
# 3                                    .45 to 64 years
# 4                                 .65 years and over
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0     16,334       15.4        9.0        3.4       10.7       19.9
# 1      2,695        2.8       12.8        6.1       10.0       23.2
# 2      6,525        7.4        8.1        3.4       10.3       27.6
# 3      4,333       15.6       10.7        3.0       11.0       17.2
# 4      2,781       45.8        4.5        1.7       11.6        2.9
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# ...

# %%
# Rename columns
noVote_2004 = noVote_2004.rename(columns = {"Table with row headers in column A and column headers in rows 5 through 7.": "Characteristic Breakdown",
                                            "Unnamed: 1": "Not Voting (in thousands)",
                                            "Unnamed: 2": "Illness or Disability (%)",
                                            "Unnamed: 3": "Out of Town (%)",
                                            "Unnamed: 4": "Forgot to Vote (%)",
                                            "Unnamed: 5": "Not Interested (%)",
                                            "Unnamed: 6": "Too Busy, Conflicting Schedule (%)",
                                            "Unnamed: 7": "Transporation Problems (%)",
                                            "Unnamed: 8" : "Did Not Like Candidates or Campaign Issues (%)",
                                            "Unnamed: 9": "Registration Problems (%)",
                                            "Unnamed: 10": "Bad Weather Conditions (%)",
                                            "Unnamed: 11": "Inconvenient Polling Place (%)",
                                            "Unnamed: 12": "Other Reason (%)",
                                            "Unnamed: 13": "Dont Know or Refused (%)"
                                            })
noVote_2004.head()
# Out:
#    index Characteristic Breakdown Not Voting (in thousands)  \
# 0      6                    TOTAL                    16,334
# 1      9          .18 to 24 years                     2,695
# 2     10          .25 to 44 years                     6,525
# 3     11          .45 to 64 years                     4,333
# 4     12       .65 years and over                     2,781
#
#   Illness or Disability (%) Out of Town (%) Forgot to Vote (%)  \
# 0                      15.4             9.0                3.4
# 1                       2.8            12.8                6.1
# 2                       7.4             8.1                3.4
# 3                      15.6            10.7                3.0
# 4                      45.8             4.5                1.7
#
#   Not Interested (%) Too Busy, Conflicting Schedule (%)  \
# 0               10.7                               19.9
# 1               10.0                               23.2
# ...

# %%
# Get rid of first column plus last column
noVote_2004.drop(['index', 'Unnamed: 14'], axis = 1, inplace = True)
noVote_2004.reset_index(inplace = True)
noVote_2004.head()
# Out:
#    index Characteristic Breakdown Not Voting (in thousands)  \
# 0      0                    TOTAL                    16,334
# 1      1          .18 to 24 years                     2,695
# 2      2          .25 to 44 years                     6,525
# 3      3          .45 to 64 years                     4,333
# 4      4       .65 years and over                     2,781
#
#   Illness or Disability (%) Out of Town (%) Forgot to Vote (%)  \
# 0                      15.4             9.0                3.4
# 1                       2.8            12.8                6.1
# 2                       7.4             8.1                3.4
# 3                      15.6            10.7                3.0
# 4                      45.8             4.5                1.7
#
#   Not Interested (%) Too Busy, Conflicting Schedule (%)  \
# 0               10.7                               19.9
# 1               10.0                               23.2
# ...

# %%
# Change 'Not Voting (in thousands)' column to deal with the comma
noVote_2004['Not Voting (in thousands)'] = noVote_2004['Not Voting (in thousands)'].str.replace(',', '').astype(int)

# Change '-' cells with zeros (census specifies this is what the dashes mean)
noVote_2004 = noVote_2004.iloc[:,:].replace('-', '0')

# %%
noVote_2004
# Out:
#     index                      Characteristic Breakdown  \
# 0       0                                         TOTAL
# 1       1                               .18 to 24 years
# 2       2                               .25 to 44 years
# 3       3                               .45 to 64 years
# 4       4                            .65 years and over
# 5       5                                         .Male
# 6       6                                       .Female
# 7       7                                  .White alone
# 8       8                    ..White non-Hispanic alone
# 9       9                                  .Black alone
# 10     10                                  .Asian alone
# 11     11                       .Hispanic (of any race)
# 12     12                .White alone or in combination
# 13     13  ..White non-Hispanic alone or in combination
# 14     14               .Black alone or in combination
# 15     15                .Asian alone or in combination
# ...

# %%
# Remove the '.' at the start of each cell for column 'Characteristic Breakdown'
for i in range(1, 20):
    noVote_2004.iloc[i,1] = (noVote_2004.iloc[i,1])[1:]

# %%
# Rows 8 and 13 have two periods, so need to remove the second
noVote_2004.iloc[8,1] = (noVote_2004.iloc[8,1])[1:]
noVote_2004.iloc[13,1] = (noVote_2004.iloc[13,1])[1:]

# %%
noVote_2004
# Out:
#     index                    Characteristic Breakdown  \
# 0       0                                       TOTAL
# 1       1                              18 to 24 years
# 2       2                              25 to 44 years
# 3       3                              45 to 64 years
# 4       4                           65 years and over
# 5       5                                        Male
# 6       6                                      Female
# 7       7                                 White alone
# 8       8                    White non-Hispanic alone
# 9       9                                 Black alone
# 10     10                                 Asian alone
# 11     11                      Hispanic (of any race)
# 12     12               White alone or in combination
# 13     13  White non-Hispanic alone or in combination
# 14     14              Black alone or in combination
# 15     15               Asian alone or in combination
# ...

# %%
type(noVote_2006['Selected Characteristics'])
# Out:
# pandas.core.series.Series

# %%
# Add Selected Characteristics column in position 1

# Creating a blank series 
Type_new = pd.Series([])

# running a for loop and asigning some values to series 
for i in range(len(noVote_2004)): 
    if noVote_2004["index"][i] >= 1 and noVote_2004["index"][i] < 5: 
        Type_new[i]="Age"
    elif noVote_2004["index"][i] >= 5 and noVote_2004["index"][i] < 7: 
        Type_new[i]="Sex"
    elif noVote_2004["index"][i] >= 7 and noVote_2004["index"][i] < 16: 
        Type_new[i]="Race and Hispanic Origin"
    elif noVote_2004["index"][i] >= 16: 
        Type_new[i]="Education attainment"  
          
# Inserting new column with values of list made above         
noVote_2004.insert(1, "Selected Characteristics", Type_new) 
  
# list output 
noVote_2004.head()
# Out:
# C:\Users\test\Anaconda3\envs\may2\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   after removing the cwd from sys.path.
#    index Selected Characteristics Characteristic Breakdown  \
# 0      0                      NaN                    TOTAL
# 1      1                      Age           18 to 24 years
# 2      2                      Age           25 to 44 years
# 3      3                      Age           45 to 64 years
# 4      4                      Age        65 years and over
#
#    Not Voting (in thousands) Illness or Disability (%) Out of Town (%)  \
# 0                      16334                      15.4             9.0
# 1                       2695                       2.8            12.8
# 2                       6525                       7.4             8.1
# ...

# %%
# Change dataframe to numeric
noVote_2004[['Illness or Disability (%)', 
             'Out of Town (%)',
             'Forgot to Vote (%)',
             'Not Interested (%)',
             'Too Busy, Conflicting Schedule (%)',
             'Transporation Problems (%)',
             'Did Not Like Candidates or Campaign Issues (%)',
             'Registration Problems (%)',
             'Bad Weather Conditions (%)',
             'Inconvenient Polling Place (%)',
             'Other Reason (%)',
             'Dont Know or Refused (%)'
            ]] = noVote_2004[['Illness or Disability (%)', 
             'Out of Town (%)',
             'Forgot to Vote (%)',
             'Not Interested (%)',
             'Too Busy, Conflicting Schedule (%)',
             'Transporation Problems (%)',
             'Did Not Like Candidates or Campaign Issues (%)',
             'Registration Problems (%)',
             'Bad Weather Conditions (%)',
             'Inconvenient Polling Place (%)',
             'Other Reason (%)',
             'Dont Know or Refused (%)'
            ]].apply(pd.to_numeric)

# %%
# Replace Selected Characteristics, though I don't know if it's necessary.  May as well since I'm here.
# First, change 'Selected Characteristics' column to string
noVote_2004['Selected Characteristics'] = noVote_2004['Selected Characteristics'].astype('str')
print(type(noVote_2004.iloc[1, 1]))
print(type(noVote_2004.iloc[2, 1]))
print(type(noVote_2004.iloc[4, 1]))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
# Save to a csv
noVote_2004.to_csv('Resources_ETL/2004_reasons_no_vote.csv')

# %% [markdown]
# # 2002
# --------
